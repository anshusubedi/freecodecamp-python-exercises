# %% [markdown]
# # Build a movie ticket calculator
# ## Python project

# %%
#In this workshop, I will show how to use booleans and conditional statements in Python by building a movie ticket booking calculator.
#Creating variables and storing the base price, age, seat_type, and show_time

base_price = 15
age = 21
seat_type = "Gold"
show_time = "Evening"

# %%
# check whether the user is allowed to book an evening show based on their age.

if age > 17:
    print('User is eligible to book a ticket')
if age >= 21:
    print('User is eligible for Evening shows')
# Out:
# User is eligible to book a ticket
# User is eligible for Evening shows

# %%
# Create a variable named is_member to indicate whether the user is a member and set its value to True.
# Create a variable named discount and set its value to 0. 
# Create an if statement to check if is_member is truthy. 
#Inside the body of the if statement, update the discount value to 3 and print User qualifies for membership discount to the terminal.

is_member = True
is_weekend = False
discount = 0
if is_member:
    discount = 3
    print('User qualifies for membership discount')
else:
    print('User does not qualify for membership discount')
    
print("Discount:",discount)
# Out:
# User qualifies for membership discount
# Discount: 3

# %%
# The membership discount should only apply to members if their age is greater than or equal to 21.
#Updating the condition of the if is_member: line by using the and operator to combine the existing condition with another condition 
## ..checking if age is greater than or equal to 21

if is_member and age >= 21:
    discount = 3
    print ("User qualifies for member discount")
print ("Discount:", discount)
# Out:
# User qualifies for member discount
# Discount: 3

# %%
# Now change the value of the is_member variable to False as the user is not a member.
#After that, you will see that the discount value now remains 0, because both conditions must be satisfied for the discount to apply.

is_member = False
is_weekend = False

discount = 0
if is_member and age >= 21:
    discount = 3
    print('User qualifies for membership discount')
else:
    print('User does not qualify for membership discount')
print('Discount:', discount)
# Out:
# User does not qualify for membership discount
# Discount: 0

# %%
# create a variable named extra_charges and set it to 0. This will represent extra charges to apply to the movie ticket on weekends.
#Then, create an if statement to check if is_weekend is truthy. Inside the body of if statement, 
#....update the extra_charges value to 2 and print Extra charges will be applied in the terminal.
# Add an else clause to your if statement and print No extra charges will be applied inside the else body. 
#This will print the message only when the extra charges condition is false.
## Then, below the else clause, use the print() call to display a message that shows Extra charges:
#....followed by the updated value of extra_charges and check the output in the terminal

extra_charges = 0

if is_weekend:
    extra_charges = 2
    print("Extra charges will be applied")
else:
    print('No extra charges will be applied')
print('Extra charges:', extra_charges)
# Out:
# No extra charges will be applied
# Extra charges: 0

# %%
# Update the condition of the if is_weekend: line by using the or operator to combine the existing condition with a second condition 
#...checking if show_time is equal to the string Evening.

extra_charges = 0
if is_weekend or show_time == "Evening":
    extra_charges = 2
   
    print('Extra charges will be applied')
else:
    print('No extra charges will be applied')
print('Extra charges:', extra_charges)
# Out:
# Extra charges will be applied
# Extra charges: 2

# %%
# check if the user satisfies the conditions to book a movie ticket. Users with age 21 or above can always book tickets without any restrictions.

if age >= 21:
    print("Ticket booking condition satisfied")
else:
    print("Ticket booking failed due to restrictions")
# Out:
# Ticket booking condition satisfied

# %%
# Users between 18 and 21 can book tickets, but only when the show_time is not Evening.
if age >= 21 or age >= 18 and (show_time != 'Evening' or is_member):
    print('Ticket booking condition satisfied')
else:
    print('Ticket booking failed due to restrictions')
# Out:
# Ticket booking condition satisfied

# %%
# calculate service charges based on the type of seat the user has selected.
if age >= 21 or age >= 18 and (show_time != 'Evening' or is_member):
    print('Ticket booking condition satisfied')
    service_charges = 0
    
    if seat_type == 'Premium':
        service_charges = 5
    else:
        pass 
else:
    print('Ticket booking failed due to restrictions')
# Out:
# Ticket booking condition satisfied

# %%
#The final price
if age >= 21 or age >= 18 and (show_time != 'Evening' or is_member):
    print('Ticket booking condition satisfied')
    service_charges = 0
    
    if seat_type == 'Premium':
        service_charges = 5
    elif seat_type == 'Gold':
        service_charges = 3
    else:
        service_charges = 1
    
    print('Service charges:', service_charges)

    # Calculate the final price
    final_price = base_price + extra_charges + service_charges - discount

    print('Final price of ticket:', final_price)

else:
    print('Ticket booking failed due to restrictions')
# Out:
# Ticket booking condition satisfied
# Service charges: 3
# Final price of ticket: 20
